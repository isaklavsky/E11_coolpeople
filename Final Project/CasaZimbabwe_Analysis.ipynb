# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("CasaZimbabwe_session1_group1_2025-05-05_15-18-30.csv")

# %%
# Convert time to datetime
# the time is in different time zone (standard time)
df['Time'] = pd.to_datetime(df['Time'], unit='s')

# %%
# Radiation Counts
plt.figure(figsize=(12, 4))
plt.plot(df['Time'], df['counts'], label='Radiation Counts')
plt.xlabel('Time')
plt.ylabel('Counts')
plt.title('Radiation Counts over Time')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Temperature
plt.figure(figsize=(12, 4))
plt.plot(df['Time'], df['Temperature'], label='Temperature (°C)', color='orange')
plt.xlabel('Time')
plt.ylabel('Temperature (°C)')
plt.title('Temperature over Time')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot PM2.5
plt.figure(figsize=(12, 4))
plt.plot(df['Time'], df['PM25'], label='PM2.5 (µg/m³)', color='green')
plt.xlabel('Time')
plt.ylabel('PM2.5 (µg/m³)')
plt.title('PM2.5 Concentration over Time')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Time', 'Latitude', 'Longitude', 'counts', 'PM1', 'PM25', 'PM10',
#        'Temperature', 'Humidity', 'Pressure', 'Altitude', 'VOC'],
#       dtype='object')

# %%
# Plot histograms and compute mean + standard deviation
variables = ['counts', 'Temperature', 'PM25']

for var in variables:
    mean_val = df[var].mean()
    std_val = df[var].std()
    print(f"{var} - Mean: {mean_val:.2f}, Standard Deviation: {std_val:.2f}")
    
    plt.figure(figsize=(8, 4))
    plt.hist(df[var], bins=30, color='skyblue', edgecolor='black')
    plt.axvline(mean_val, color='red', linestyle='dashed', linewidth=1.5, label=f'Mean = {mean_val:.2f}')
    plt.axvline(mean_val + std_val, color='green', linestyle='dotted', linewidth=1.5, label=f'+1σ = {mean_val + std_val:.2f}')
    plt.axvline(mean_val - std_val, color='green', linestyle='dotted', linewidth=1.5, label=f'-1σ = {mean_val - std_val:.2f}')
    plt.title(f'{var} Distribution')
    plt.xlabel(var)
    plt.ylabel('Frequency')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# counts - Mean: 25.71, Standard Deviation: 2.13
# Temperature - Mean: 30.09, Standard Deviation: 0.53
# PM25 - Mean: 2.55, Standard Deviation: 0.73

# %%
import numpy as np

# Compare expected vs. measured standard deviation for counts

# Counts data
mean_counts = df['counts'].mean()
std_measured = df['counts'].std()
n_samples = len(df)

# Expected standard deviation from counting statistics
std_expected = np.sqrt(mean_counts)

# Uncertainty on measured std dev using CLT
uncertainty_std = std_expected / np.sqrt(2 * np.sqrt(n_samples))

print(f"Mean Counts (N): {mean_counts:.2f}")
print(f"Expected Std Dev (√N): {std_expected:.2f}")
print(f"Measured Std Dev: {std_measured:.2f}")
print(f"Uncertainty on Measured Std Dev: ±{uncertainty_std:.2f}")

if abs(std_measured - std_expected) <= uncertainty_std:
    print("→ The measured and expected standard deviations are in statistical agreement.")
else:
    print("→ The measured and expected standard deviations are NOT in statistical agreement.")
# Out:
# Mean Counts (N): 25.71
# Expected Std Dev (√N): 5.07
# Measured Std Dev: 2.13
# Uncertainty on Measured Std Dev: ±0.90
# → The measured and expected standard deviations are NOT in statistical agreement.

# %%
# Round latitude and longitude
df['LatLng'] = df['Latitude'].round(5).astype(str) + "," + df['Longitude'].round(5).astype(str)

# Group
location_stats = df.groupby('LatLng')['counts'].agg(['mean', 'std', 'count']).reset_index()
location_stats['sem'] = location_stats['std'] / np.sqrt(location_stats['count'])

# Display locations and stats
print("Radiation by Location")
for _, row in location_stats.iterrows():
    print(f"Location {row['LatLng']}: Mean = {row['mean']:.2f}, SEM = ±{row['sem']:.2f}")
# Out:
# Radiation by Location
# Location 37.87555,-122.26096: Mean = 22.20, SEM = ±nan
# Location 37.87556,-122.26093: Mean = 21.80, SEM = ±nan
# Location 37.87557,-122.26094: Mean = 26.40, SEM = ±0.60
# Location 37.87558,-122.26094: Mean = 28.80, SEM = ±nan
# Location 37.87558,-122.26098: Mean = 30.20, SEM = ±nan
# Location 37.87558,-122.26103: Mean = 24.80, SEM = ±0.20
# Location 37.87559,-122.26092: Mean = 26.20, SEM = ±nan
# Location 37.87559,-122.26096: Mean = 23.60, SEM = ±0.00
# Location 37.87559,-122.26098: Mean = 26.00, SEM = ±nan
# Location 37.8756,-122.26091: Mean = 26.33, SEM = ±1.25
# Location 37.8756,-122.26093: Mean = 24.20, SEM = ±nan
# Location 37.8756,-122.26094: Mean = 28.00, SEM = ±nan
# Location 37.8756,-122.26097: Mean = 28.20, SEM = ±nan
# Location 37.8756,-122.261: Mean = 26.00, SEM = ±nan
# Location 37.87561,-122.26089: Mean = 23.90, SEM = ±2.10
# Location 37.87561,-122.26094: Mean = 23.80, SEM = ±nan
# Location 37.87561,-122.26095: Mean = 21.90, SEM = ±1.10
# Location 37.87561,-122.26097: Mean = 26.35, SEM = ±0.94
# Location 37.87561,-122.26099: Mean = 24.60, SEM = ±nan
# Location 37.87561,-122.26114: Mean = 23.80, SEM = ±nan
# Location 37.87561,-122.26115: Mean = 25.96, SEM = ±0.75
# Location 37.87562,-122.26088: Mean = 25.40, SEM = ±2.20
# Location 37.87562,-122.2609: Mean = 25.00, SEM = ±0.20
# Location 37.87562,-122.26091: Mean = 25.60, SEM = ±nan
# Location 37.87562,-122.26093: Mean = 27.20, SEM = ±3.00
# Location 37.87562,-122.26094: Mean = 23.20, SEM = ±nan
# Location 37.87562,-122.26095: Mean = 25.05, SEM = ±0.64
# Location 37.87562,-122.26096: Mean = 24.33, SEM = ±0.64
# Location 37.87562,-122.26097: Mean = 26.50, SEM = ±0.30
# Location 37.87562,-122.26098: Mean = 26.60, SEM = ±2.60
# Location 37.87562,-122.26099: Mean = 23.50, SEM = ±0.56
# Location 37.87562,-122.261: Mean = 23.20, SEM = ±1.20
# Location 37.87562,-122.26101: Mean = 25.60, SEM = ±0.80
# Location 37.87562,-122.26102: Mean = 26.20, SEM = ±nan
# Location 37.87563,-122.26088: Mean = 28.20, SEM = ±nan
# Location 37.87563,-122.26093: Mean = 25.80, SEM = ±nan
# Location 37.87563,-122.26094: Mean = 24.70, SEM = ±1.90
# Location 37.87563,-122.26095: Mean = 26.55, SEM = ±0.88
# Location 37.87563,-122.26096: Mean = 25.07, SEM = ±2.21
# Location 37.87563,-122.26099: Mean = 23.40, SEM = ±0.81
# Location 37.87563,-122.261: Mean = 23.80, SEM = ±nan
# Location 37.87563,-122.26101: Mean = 24.40, SEM = ±nan
# Location 37.87563,-122.26109: Mean = 25.40, SEM = ±nan
# Location 37.87563,-122.26111: Mean = 25.80, SEM = ±nan
# Location 37.87563,-122.26113: Mean = 26.60, SEM = ±nan
# Location 37.87564,-122.2609: Mean = 27.60, SEM = ±0.80
# Location 37.87564,-122.26092: Mean = 25.00, SEM = ±0.40
# Location 37.87564,-122.26094: Mean = 26.30, SEM = ±0.53
# Location 37.87564,-122.26095: Mean = 24.20, SEM = ±nan
# Location 37.87564,-122.26096: Mean = 26.60, SEM = ±1.64
# Location 37.87564,-122.26097: Mean = 22.20, SEM = ±nan
# Location 37.87564,-122.26101: Mean = 28.80, SEM = ±nan
# Location 37.87564,-122.2611: Mean = 26.70, SEM = ±1.30
# Location 37.87565,-122.26084: Mean = 27.20, SEM = ±nan
# Location 37.87565,-122.26088: Mean = 27.32, SEM = ±1.56
# Location 37.87565,-122.26089: Mean = 24.60, SEM = ±nan
# Location 37.87565,-122.2609: Mean = 26.60, SEM = ±1.20
# Location 37.87565,-122.26091: Mean = 26.00, SEM = ±nan
# Location 37.87565,-122.26093: Mean = 24.20, SEM = ±nan
# Location 37.87565,-122.26094: Mean = 23.00, SEM = ±nan
# Location 37.87565,-122.26095: Mean = 25.20, SEM = ±nan
# Location 37.87565,-122.26096: Mean = 24.80, SEM = ±1.80
# Location 37.87565,-122.26097: Mean = 26.13, SEM = ±0.44
# Location 37.87565,-122.26098: Mean = 25.97, SEM = ±1.39
# Location 37.87565,-122.26099: Mean = 22.70, SEM = ±2.70
# Location 37.87565,-122.261: Mean = 26.00, SEM = ±nan
# Location 37.87565,-122.26102: Mean = 26.20, SEM = ±nan
# Location 37.87566,-122.26085: Mean = 25.40, SEM = ±nan
# Location 37.87566,-122.26087: Mean = 26.80, SEM = ±nan
# Location 37.87566,-122.26088: Mean = 22.40, SEM = ±nan
# Location 37.87566,-122.26092: Mean = 28.20, SEM = ±nan
# Location 37.87566,-122.26094: Mean = 26.50, SEM = ±1.10
# Location 37.87566,-122.26095: Mean = 25.40, SEM = ±1.08
# Location 37.87566,-122.26096: Mean = 26.80, SEM = ±0.56
# Location 37.87566,-122.26097: Mean = 25.28, SEM = ±0.80
# Location 37.87566,-122.26098: Mean = 24.50, SEM = ±1.10
# Location 37.87566,-122.261: Mean = 24.40, SEM = ±nan
# Location 37.87567,-122.26089: Mean = 23.80, SEM = ±0.20
# Location 37.87567,-122.2609: Mean = 26.40, SEM = ±nan
# Location 37.87567,-122.26091: Mean = 24.40, SEM = ±nan
# Location 37.87567,-122.26092: Mean = 24.80, SEM = ±2.00
# Location 37.87567,-122.26093: Mean = 29.30, SEM = ±1.10
# Location 37.87567,-122.26095: Mean = 27.00, SEM = ±0.23
# Location 37.87567,-122.26096: Mean = 24.80, SEM = ±0.82
# Location 37.87567,-122.26097: Mean = 25.30, SEM = ±0.82
# Location 37.87567,-122.26098: Mean = 24.93, SEM = ±1.38
# Location 37.87567,-122.26099: Mean = 25.67, SEM = ±0.47
# Location 37.87567,-122.261: Mean = 25.40, SEM = ±nan
# Location 37.87567,-122.26104: Mean = 23.80, SEM = ±nan
# Location 37.87568,-122.26086: Mean = 24.80, SEM = ±nan
# Location 37.87568,-122.26089: Mean = 25.60, SEM = ±nan
# Location 37.87568,-122.2609: Mean = 25.30, SEM = ±1.30
# Location 37.87568,-122.26091: Mean = 26.00, SEM = ±nan
# Location 37.87568,-122.26093: Mean = 28.60, SEM = ±nan
# Location 37.87568,-122.26096: Mean = 28.27, SEM = ±1.55
# Location 37.87568,-122.26099: Mean = 27.27, SEM = ±1.43
# Location 37.87569,-122.26084: Mean = 24.80, SEM = ±0.80
# Location 37.87569,-122.26085: Mean = 25.10, SEM = ±0.90
# Location 37.87569,-122.26089: Mean = 27.60, SEM = ±nan
# Location 37.87569,-122.2609: Mean = 23.20, SEM = ±nan
# Location 37.87569,-122.26091: Mean = 23.50, SEM = ±0.10
# Location 37.87569,-122.26093: Mean = 23.60, SEM = ±nan
# Location 37.87569,-122.26094: Mean = 26.60, SEM = ±0.20
# Location 37.87569,-122.26095: Mean = 28.27, SEM = ±1.46
# Location 37.87569,-122.26097: Mean = 27.00, SEM = ±0.60
# Location 37.87569,-122.26098: Mean = 27.00, SEM = ±1.80
# Location 37.87569,-122.261: Mean = 25.20, SEM = ±nan
# Location 37.8757,-122.26084: Mean = 27.00, SEM = ±nan
# Location 37.8757,-122.26086: Mean = 27.20, SEM = ±nan
# Location 37.8757,-122.26087: Mean = 26.80, SEM = ±nan
# Location 37.8757,-122.26089: Mean = 28.40, SEM = ±nan
# Location 37.8757,-122.26093: Mean = 25.80, SEM = ±nan
# Location 37.8757,-122.26094: Mean = 25.58, SEM = ±0.43
# Location 37.8757,-122.26095: Mean = 27.07, SEM = ±1.98
# Location 37.8757,-122.26098: Mean = 28.40, SEM = ±nan
# Location 37.8757,-122.26105: Mean = 24.00, SEM = ±nan
# Location 37.87571,-122.26082: Mean = 24.10, SEM = ±0.10
# Location 37.87571,-122.26083: Mean = 29.00, SEM = ±nan
# Location 37.87571,-122.26095: Mean = 23.40, SEM = ±nan
# Location 37.87571,-122.26096: Mean = 26.40, SEM = ±nan
# Location 37.87571,-122.26097: Mean = 29.00, SEM = ±nan
# Location 37.87573,-122.26092: Mean = 22.70, SEM = ±0.70
# Location 37.87573,-122.26096: Mean = 28.40, SEM = ±nan
# Location 37.87573,-122.26098: Mean = 25.40, SEM = ±nan
# Location 37.87574,-122.26087: Mean = 29.40, SEM = ±nan
# Location 37.87575,-122.26084: Mean = 27.10, SEM = ±0.30
# Location 37.87575,-122.26086: Mean = 26.00, SEM = ±nan
# Location 37.87575,-122.26088: Mean = 23.80, SEM = ±nan
# Location 37.87577,-122.26083: Mean = 26.80, SEM = ±nan
# Location 37.87579,-122.26087: Mean = 26.60, SEM = ±nan
# Location 37.8758,-122.26084: Mean = 30.00, SEM = ±nan
# Location 37.87598,-122.26099: Mean = 29.20, SEM = ±nan

# %%
# Sort locations by mean counts for readability
location_stats_sorted = location_stats.sort_values(by='mean', ascending=False)

plt.figure(figsize=(14, 6))
plt.bar(location_stats_sorted['LatLng'], location_stats_sorted['mean'], yerr=location_stats_sorted['sem'],
        capsize=4, color='skyblue', edgecolor='black')
plt.xticks(rotation=90, fontsize=8)
plt.xlabel('Location')
plt.ylabel('Mean Radiation Counts')
plt.title('Mean Radiation Counts by Location')
plt.tight_layout()
plt.grid(axis='y')
plt.show()
