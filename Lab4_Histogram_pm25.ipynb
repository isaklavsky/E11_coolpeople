# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = "pm25.csv"  # Ensure the file is in the same directory as this script
df = pd.read_csv(file_path)

# %%
# Print column names to debug issues
print("Columns in dataset:", df.columns)
# Out:
# Columns in dataset: Index(['Time', 'PM 1.0: %d', 'PM2.5: %d', 'PM10: %d',
#        'Particles > 0.3um / 0.1L air', 'Particles > 0.5um / 0.1L air',
#        'Particles > 1.0um / 0.1L air', 'Particles > 2.5um / 0.1L air',
#        'Particles > 5.0um / 0.1L air', 'Particles > 10um / 0.1L air'],
#       dtype='object')

# %%
# Convert columns to numeric in case of data type issues
for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Plot histograms for all columns
plt.figure(figsize=(10, 6))

# Group similar data together for better visualization
similar_cols = [col for col in df.columns if "PM" in col]
for col in similar_cols:
    plt.hist(df[col].dropna(), bins=20, alpha=0.6, label=col.replace("\t", " "), edgecolor='black')

plt.xlabel("Concentration (µg/m³)")
plt.ylabel("Frequency")
plt.title("Frequency Distribution of PM Data")
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# Plot histograms separately for other particle counts
for col in df.columns:
    if col not in similar_cols and col != "Time":
        plt.figure(figsize=(8, 5))
        plt.hist(df[col].dropna(), bins=20, edgecolor='black', alpha=0.7)
        plt.xlabel("Count")
        plt.ylabel("Frequency")
        plt.title(f"Frequency Distribution of {col.replace('\t', ' ')}")
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.show()

# %%
# Plot histograms separately for other particle counts
for col in df.columns:
    if col not in similar_cols and col != "Time":
        plt.figure(figsize=(8, 5))
        plt.hist(df[col], bins=20, edgecolor='black', alpha=0.7)
        plt.xlabel("Count")
        plt.ylabel("Frequency")
        plt.title(f"Frequency Distribution of {col.replace('\t', ' ')}")
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.show()
